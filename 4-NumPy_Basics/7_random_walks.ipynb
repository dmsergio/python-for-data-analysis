# %% [markdown]
# Veamos en primer lugar como construir un "Random walks" con el modulo random incorporado en Python.

# %%
import random

# %%
position = 0
walk = [position]
steps = 1000
for i in range(steps):
    step = random.randint(0, 1) and 1 or 0
    position += step
    walk.append(position)
walk
# Out:
# [0,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  2,
#  2,
#  2,
#  3,
#  3,
#  4,
#  4,
#  4,
#  4,
#  5,
#  6,
#  7,
#  8,
#  8,
#  9,
#  9,
#  10,
#  11,
#  11,
#  12,
#  12,
#  12,
#  13,
#  14,
#  14,
#  15,
#  15,
#  16,
#  16,
#  16,
#  17,
#  18,
#  18,
#  19,
#  19,
#  20,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  21,
#  22,
#  22,
#  23,
#  23,
#  24,
#  24,
#  24,
#  25,
#  26,
#  26,
#  27,
#  28,
#  29,
#  29,
#  30,
#  30,
#  31,
#  31,
#  31,
#  31,
#  32,
#  32,
#  33,
#  33,
#  34,
#  34,
#  35,
#  36,
#  36,
#  36,
#  36,
#  37,
#  37,
#  37,
#  37,
#  37,
#  38,
#  39,
#  39,
#  40,
#  41,
#  41,
#  42,
#  42,
#  42,
#  43,
#  44,
#  44,
#  45,
#  45,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  46,
#  47,
#  47,
#  47,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  48,
#  49,
#  49,
#  50,
#  51,
#  51,
#  52,
#  52,
#  52,
#  52,
#  52,
#  52,
#  53,
#  54,
#  55,
#  55,
#  56,
#  57,
#  58,
#  58,
#  58,
#  58,
#  58,
#  58,
#  59,
#  60,
#  61,
#  61,
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(walk[:100])

# %% [markdown]
# Ahora se ve a utilizar el módulo random de NumPy para dibujar el lanzamiento de 1000 monedas al mismo tiempo.

# %%
import numpy as np
nsteps = 1000
draws = np.random.randint(0, 2, size=nsteps)
steps = np.where(draws > 0, 1, -1)
walk = steps.cumsum()

# %%
walk.min()
# Out:
# -15

# %%
walk.max()
# Out:
# 38

# %%
plt.plot(walk[:100])

# %%
(np.abs(walk) >= 10).argmax()
# Out:
# 87

# %% [markdown]
# Simulando varios "Random walks" al mismo tiempo

# %%
nwalks = 5000
nsteps = 1000
draws = np.random.randint(0, 2, size=(nwalks, nsteps))
steps = np.where(draws > 0, 1, -1)
walks = steps.cumsum(1)
walks
# Out:
# array([[-1,  0,  1, ..., -6, -7, -8],
#        [ 1,  0, -1, ..., 40, 39, 38],
#        [ 1,  0, -1, ..., 26, 27, 26],
#        ...,
#        [-1,  0,  1, ..., -2, -3, -2],
#        [-1,  0,  1, ..., -4, -3, -4],
#        [ 1,  2,  3, ..., 44, 43, 42]])

# %%
walks.min()
# Out:
# -111

# %%
walks.max()
# Out:
# 113
